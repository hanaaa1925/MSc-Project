# %%
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import roc_curve,auc
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# nltk用于文本预处理
from nltk import data
from nltk import download
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, RegexpTokenizer

# %%
import stanza
stanza.download('en')
nlp = stanza.Pipeline(lang='en', processors='tokenize,ner')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2021-11-15 00:05:27 INFO: Downloading default packages for language: en (English)...
# 2021-11-15 00:05:28 INFO: File exists: /Users/yhl125/stanza_resources/en/default.zip.
# 2021-11-15 00:05:33 INFO: Finished downloading models and saved to /Users/yhl125/stanza_resources.
# 2021-11-15 00:05:33 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | ner       | ontonotes |
# =========================
#
# 2021-11-15 00:05:33 INFO: Use device: cpu
# 2021-11-15 00:05:33 INFO: Loading: tokenize
# 2021-11-15 00:05:33 INFO: Loading: ner
# 2021-11-15 00:05:33 INFO: Done loading processors!

# %%
data = pd.read_excel('./dataset.xlsx')
data
# Out:
#                                                content  label
# 0    @Ricardo70078700 I have a big problem buying f...      0
# 1    RT @tconnellyRTE : 6/ “One colleague working o...      0
# 2    RT @joncstone : In case you missed this from m...      0
# 3    RT @AlexandravonNah : EU climate chief: 'We ne...      0
# 4    RT @Fourens__ : My colleague just told me she ...      0
# ..                                                 ...    ...
# 495  If I want to change my job, a fortune 500 comp...      1
# 496  I can't stand this awful working environment, ...      1
# 497  Tired, do not want to go to work, began and lo...      1
# 498  Overtime overtime. Fuck overtime. I don't want...      1
# 499  The boss never works overtime, because the bos...      1
#
# [500 rows x 2 columns]

# %%
print('包含{}条推文'.format(data.shape[0]))
print('无敏感信息推文有{}条'.format(data['label'].value_counts()[0]))
print('有敏感信息推文有{}条'.format(data['label'].value_counts()[1]))
# Out:
# 包含500条推文
# 无敏感信息推文有295条
# 有敏感信息推文有205条

# %%
plt.style.use('seaborn')
plt.figure(figsize=(5,3), dpi=100)
data['label'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['content'] = data['content'].str.lower()
data.head()
# Out:
#                                              content  label
# 0  @ricardo70078700 i have a big problem buying f...      0
# 1  rt @tconnellyrte : 6/ “one colleague working o...      0
# 2  rt @joncstone : in case you missed this from m...      0
# 3  rt @alexandravonnah : eu climate chief: 'we ne...      0
# 4  rt @fourens__ : my colleague just told me she ...      0

# %%
data['content'] = data['content'].apply(lambda string: ' '.join([word for word in string.split(' ') if not word.rstrip(' ').startswith('@')]))
data['content'] = data['content'].apply(lambda string: ' '.join([word for word in string.split(' ') if not word.rstrip(' ').startswith('#')]))
data['content'] = data['content'].apply(lambda string: ' '.join([word for word in string.split(' ') if not word.rstrip(' ').startswith('http')]))

data.head()
# Out:
#                                              content  label
# 0  i have a big problem buying from all the metho...      0
# 1  rt : 6/ “one colleague working on ni was nearl...      0
# 2     rt : in case you missed this from my colleague      0
# 3  rt : eu climate chief: 'we need to be more amb...      0
# 4  rt : my colleague just told me she bought a ho...      0

# %%
stop_words = set(stopwords.words('english'))
stop_words.add('rt')

# %%
def text_process(text):
    tokenizer = RegexpTokenizer('[a-z0-9]+')
    token = tokenizer.tokenize(text)
    lemmatizer = WordNetLemmatizer()
    token = [lemmatizer.lemmatize(w) for w in token if lemmatizer.lemmatize(w) not in stop_words]
    return token

# %%
data['content'] = data['content'].apply(text_process)

# %%
data
# Out:
#                                                content  label
# 0    [big, problem, buying, method, country, accept...      0
# 1    [6, one, colleague, working, ni, wa, nearly, t...      0
# 2                            [case, missed, colleague]      0
# 3    [eu, climate, chief, need, ambitious, frans, t...      0
# 4    [colleague, told, bought, house, wa, gifted, 3...      0
# ..                                                 ...    ...
# 495  [want, change, job, fortune, 500, company, giv...      1
# 496  [stand, awful, working, environment, going, ju...      1
# 497  [tired, want, go, work, began, long, term, job...      1
# 498  [overtime, overtime, fuck, overtime, want, ove...      1
# 499  [bos, never, work, overtime, bos, best, work, ...      1
#
# [500 rows x 2 columns]

# %%
X = data['content']
y = data['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

# %%
train
# Out:
#                                                content  label
# 312                                        [fuck, bos]      1
# 341  [crideble, info, 2000, alqaeda, prisoner, rele...      1
# 168  [past, year, ha, undeniably, challenging, test...      0
# 285  [sleeping, giant, 1, p2e, game, 2, whitepaper,...      0
# 129  [name, singalakha, hold, ndip, logistics, nels...      0
# ..                                                 ...    ...
# 296  [several, hour, game, none, team, india, membe...      1
# 173  [set, successfully, worst, common, mistake, id...      0
# 366  [adulting, lot, man, feeling, like, constant, ...      1
# 100  [run, loss, making, company, pay, salary, rent...      0
# 322  [sleeping, bos, choice, melt, leave, job, matt...      1
#
# [400 rows x 2 columns]

# %%
print(train['label'].value_counts())
plt.figure(figsize=(5,5), dpi=100)
train['label'].value_counts().plot(kind='bar')
# Out:
# 0    231
# 1    169
# Name: label, dtype: int64
# <AxesSubplot:>

# %%
print(test['label'].value_counts())
plt.figure(figsize=(5,3), dpi=100)
test['label'].value_counts().plot(kind='bar')
# Out:
# 0    64
# 1    36
# Name: label, dtype: int64
# <AxesSubplot:>

# %%
non_sensitive_train = train[train['label'] == 0]
sensitive_train = train[train['label'] == 1]

# %%
non_sensitive_train
# Out:
#                                                content  label
# 168  [past, year, ha, undeniably, challenging, test...      0
# 285  [sleeping, giant, 1, p2e, game, 2, whitepaper,...      0
# 129  [name, singalakha, hold, ndip, logistics, nels...      0
# 34   [sequel, likely, according, warnermedia, studi...      0
# 213  [united, nation, recognizes, amp, acknowledges...      0
# ..                                                 ...    ...
# 289  [effortlessly, time, different, source, income...      0
# 50   [guess, prudent, note, adhd, work, coffee, sho...      0
# 282  [obviously, raising, income, level, par, rest,...      0
# 173  [set, successfully, worst, common, mistake, id...      0
# 100  [run, loss, making, company, pay, salary, rent...      0
#
# [231 rows x 2 columns]

# %%
# non_sensitive_train_part = non_sensitive_train['content'].sample(139, random_state=42)
# sensitive_train_part = sensitive_train['content'].sample(139, random_state=42)

non_sensitive_trainset = non_sensitive_train['content']
sensitive_trainset = sensitive_train['content']

vocablist = []
for i in pd.concat([non_sensitive_trainset, sensitive_trainset]):
    vocablist += i

# %%
vocablist
# Out:
# ['past',
#  'year',
#  'ha',
#  'undeniably',
#  'challenging',
#  'testing',
#  'physical',
#  'mental',
#  'emotional',
#  'health',
#  'help',
#  'motivational',
#  'advice',
#  'savvy',
#  'strategy',
#  'staving',
#  'burnout',
#  'turned',
#  'brittnea',
#  'jones',
#  'parkview',
#  'behavioral',
#  'health',
#  'institute',
#  'sleeping',
#  'giant',
#  '1',
#  'p2e',
#  'game',
#  '2',
#  'whitepaper',
#  'drop',
#  'month',
#  '3',
#  'savior',
#  'mint',
#  'month',
#  '4',
#  'breeding',
#  'delivered',
#  'q1',
#  '2022',
#  '5',
#  'game',
#  'launch',
#  'q2',
#  '22',
#  '6',
#  'breeding',
#  'stud',
#  'service',
#  'gameplay',
#  'rental',
#  'passive',
#  'income',
#  'project',
#  'boom',
#  'name',
#  'singalakha',
#  'hold',
#  'ndip',
#  'logistics',
#  'nelson',
#  'mandela',
#  'uni',
#  'looking',
#  'job',
#  'past',
#  '5months',
#  'amp',
#  '2',
#  'year',
#  'experience',
#  'previous',
#  'internship',
#  'appealing',
#  'post',
#  'available',
#  'regard',
#  'job',
#  'post',
#  'available',
#  'aligned',
#  'profession',
#  'sequel',
#  'likely',
#  'according',
#  'warnermedia',
#  'studio',
#  'bos',
#  'http',
#  'co',
#  'bfy7eelbih',
#  'united',
#  'nation',
#  'recognizes',
#  'amp',
#  'acknowledges',
#  'persecution',
#  'hindu',
#  'minority',
#  'asmt',
#  'woman',
#  'report',
#  'published',
#  'two',
#  'drunk',
#  'lady',
#  'work',
#  'asked',
#  'wanted',
#  'take',
#  'selfie',
#  'wa',
#  'like',
#  'um',
#  'ok',
#  'said',
#  'bos',
#  'deserved',
#  'payrise',
#  'fairness',
#  'galing',
#  'nung',
#  'boy',
#  'type',
#  'ko',
#  'premise',
#  'self',
#  'identify',
#  'part',
#  'group',
#  'premise',
#  'certain',
#  'group',
#  'preferential',
#  'treatment',
#  'equity',
#  'aka',
#  'social',
#  'justice',
#  'result',
#  'unscrupulous',
#  'individual',
#  'identify',
#  'part',
#  'preferred',
#  'group',
#  'sowing',
#  'resentment',
#  'solution',
#  'equality',
#  'meritocracy',
#  'fairness',
#  'tho',
#  'alan',
#  'wrong',
#  'lineker',
#  'tweet',
#  'like',
#  'celebs',
#  'speak',
#  'outside',
#  'area',
#  'exactly',
#  'improved',
#  'level',
#  'public',
#  'discourse',
#  'ha',
#  'alan',
#  'get',
#  'quote',
#  'tweeted',
#  'amp',
#  'put',
#  'article',
#  'like',
#  'sum',
#  'lot',
#  'wrong',
#  'twitter',
#  'hi',
#  'fighting',
#  'burnout',
#  'reform',
#  'wheel',
#  'rule',
#  'case',
#  'missed',
#  'colleague',
#  'great',
#  'oppose',
#  'racism',
#  'showed',
#  'empathy',
#  'black',
#  'american',
#  'try',
#  'get',
#  'stand',
#  'colleague',
#  'fellow',
#  'indian',
#  'player',
#  'mohammed',
#  'shami',
#  'show',
#  'oppose',
#  'communalism',
#  'west',
#  'virginia',
#  '2nd',
#  'poorest',
#  'state',
#  'u',
#  'rank',
#  '50th',
#  'education',
#  '48th',
#  'household',
#  'income',
#  'maybe',
#  'rest',
#  '700k',
#  'yacht',
#  'think',
#  'need',
#  'constituent',
#  'pay',
#  'salary',
#  'city',
#  'fan',
#  'probably',
#  'noticed',
#  'since',
#  '100m',
#  'move',
#  'fairness',
#  'lmaooo',
#  'asking',
#  'mom',
#  'permission',
#  'could',
#  'buy',
#  'seventeen',
#  'album',
#  'still',
#  'answer',
#  'nowhere',
#  'ask',
#  'bts',
#  'one',
#  'advertise',
#  'lazada',
#  'rn',
#  'like',
#  'mnnhnhnhnhhn',
#  'seventeen',
#  'well',
#  'bts',
#  'seventeen',
#  'workmate',
#  'guess',
#  'hay',
#  'nagresign',
#  'one',
#  'favorite',
#  'workmate',
#  'hay',
#  'kkalungkot',
#  'using',
#  'shamita',
#  'fairness',
#  'loyal',
#  'attitude',
#  'advantage',
#  'shamita',
#  'must',
#  'aware',
#  'work',
#  'week',
#  'fixing',
#  'food',
#  'others',
#  'meal',
#  'fix',
#  'would',
#  'awesome',
#  'sunsets53',
#  'funny',
#  'dropped',
#  'social',
#  'distancing',
#  'lockdown',
#  'quickly',
#  'work',
#  'brought',
#  'someone',
#  'wa',
#  'strict',
#  'back',
#  'want',
#  'talk',
#  'guess',
#  'urgent',
#  'job',
#  'seeker',
#  'need',
#  'employability',
#  'boost',
#  'get',
#  'cv',
#  'reviewed',
#  'free',
#  'hr',
#  'professional',
#  'info',
#  'transmission',
#  'short',
#  'range',
#  'yeah',
#  'airborne',
#  'disease',
#  'work',
#  'tuberculosis',
#  'spread',
#  'simple',
#  'probability',
#  'dispersion',
#  'comment',
#  'mechanism',
#  'transmission',
#  'ha',
#  'lot',
#  'documented',
#  'long',
#  'range',
#  'covid',
#  'transmission',
#  'please',
#  'kill',
#  'filibuster',
#  'please',
#  'inact',
#  'fairness',
#  'doctrine',
#  'please',
#  'stop',
#  'worrying',
#  'seen',
#  'great',
#  'compromiser',
#  'one',
#  'compromise',
#  'fascist',
#  'criminal',
#  'anyway',
#  'lord',
#  'chamberlain',
#  'mistake',
#  'please',
#  'review',
#  '14th',
#  'amendment',
#  'section',
#  '3',
#  'job',
#  'wel',
#  'ariastaylorswift',
#  'weekend',
#  'tsa',
#  'nou',
#  'di',
#  'batla',
#  'inheritance',
#  'salary',
#  'reaching',
#  'burnout',
#  'ha',
#  'nothing',
#  'sunflower',
#  'amp',
#  'sunshine',
#  'nobody',
#  'care',
#  'enough',
#  'really',
#  'get',
#  'validate',
#  'experience',
#  'take',
#  'care',
#  'fine',
#  'hello',
#  'husband',
#  'searching',
#  'job',
#  'plz',
#  'help',
#  'short',
#  'profile',
#  'current',
#  'profile',
#  'seo',
#  'related',
#  'php',
#  'coding',
#  'website',
#  'maintenance',
#  'looking',
#  'change',
#  'job',
#  'profile',
#  'wordpress',
#  'developer',
#  'php',
#  'developer',
#  'plz',
#  'help',
#  'thank',
#  'talaga',
#  'sa',
#  'workmate',
#  'kong',
#  'tinapos',
#  'lahat',
#  'kahapon',
#  'lahat',
#  'ng',
#  'email',
#  'query',
#  'ko',
#  'hahahaha',
#  'encoding',
#  'na',
#  'lang',
#  'natira',
#  'lt',
#  '3',
#  'still',
#  'forward',
#  'player',
#  'job',
#  'score',
#  'like',
#  'kane',
#  'robertson',
#  'arnold',
#  'technically',
#  'liverpool',
#  'winger',
#  'going',
#  'love',
#  'find',
#  'job',
#  'create',
#  'art',
#  'love',
#  'feel',
#  'powerful',
#  'going',
#  'back',
#  'track',
#  'know',
#  'going',
#  'feel',
#  'like',
#  'eventually',
#  'end',
#  'hang',
#  'decarbonization',
#  'mean',
#  'enormous',
#  'transfer',
#  'wealth',
#  'income',
#  'oil',
#  'producer',
#  'oil',
#  'consumer',
#  'even',
#  'oil',
#  'consumer',
#  'also',
#  'lead',
#  'renewables',
#  'europe',
#  'far',
#  'east',
#  'big',
#  'winner',
#  'u',
#  'norway',
#  'et',
#  'al',
#  'probably',
#  'adjust',
#  'opec',
#  'big',
#  'loser',
#  'ha',
#  'tujhe',
#  'bohot',
#  'pata',
#  'hai',
#  'ipl',
#  'ke',
#  'match',
#  'dekhne',
#  'k',
#  'liye',
#  'paisa',
#  'bhi',
#  'hote',
#  'hai',
#  'kya',
#  'tere',
#  'pas',
#  'loudu',
#  'psl',
#  'ki',
#  'trophy',
#  'ki',
#  'kimat',
#  'se',
#  'jyada',
#  'ipl',
#  'k',
#  'ek',
#  'player',
#  'ki',
#  'salary',
#  'hai',
#  'climate',
#  'action',
#  'vehicle',
#  'deliver',
#  'dignity',
#  'opportunity',
#  'equality',
#  'ahead',
#  'watch',
#  'deputy',
#  'secretary',
#  'general',
#  'remark',
#  '6',
#  'way',
#  'company',
#  'help',
#  'employee',
#  'overcome',
#  'burnout',
#  'distributed',
#  'world',
#  'colleague',
#  'told',
#  'bought',
#  'house',
#  'wa',
#  'gifted',
#  '30k',
#  'grandma',
#  'kind',
#  'wealth',
#  'trying',
#  'sew',
#  'kid',
#  'grandkids',
#  'life',
#  'frugal',
#  'life',
#  'putting',
#  'extra',
#  'money',
#  'salary',
#  'invest',
#  'extra',
#  'income',
#  'give',
#  'room',
#  'spend',
#  'want',
#  'quality',
#  'product',
#  'loveeee',
#  'life',
#  'meditate',
#  'way',
#  'burnout',
#  'regular',
#  'mindfulness',
#  'meditation',
#  'help',
#  'work',
#  'regular',
#  'support',
#  'thing',
#  'get',
#  'tough',
#  'brother',
#  'remember',
#  'salary',
#  'ilu',
#  'le',
#  'country',
#  'strong',
#  'think',
#  'enough',
#  'ha',
#  'said',
#  'heavy',
#  'lifting',
#  'australian',
#  'psychologist',
#  'especially',
#  'melbourne',
#  'done',
#  'pandemic',
#  'frontline',
#  'worker',
#  'struggling',
#  'burnout',
#  'saved',
#  'countless',
#  'life',
#  'gp',
#  'feel',
#  'indebted',
#  'interested',
#  'bacterial',
#  'cell',
#  'biology',
#  'genetics',
#  'phd',
#  'position',
#  'open',
#  'group',
#  'lund',
#  'university',
#  'study',
#  'control',
#  'polar',
#  'growth',
#  'cell',
#  'shape',
#  'streptomyces',
#  'apply',
#  'nov',
#  '12',
#  'info',
#  'goal',
#  'gender',
#  'equality',
#  'gender',
#  'harmony',
#  'excellent',
#  'conversation',
#  'access',
#  'justice',
#  'small',
#  'claim',
#  'court',
#  'revolutionary',
#  'court',
#  'unique',
#  'innovation',
#  'broaden',
#  'access',
#  'justice',
#  'way',
#  'previously',
#  'thought',
#  'unachievable',
#  'judiciary',
#  'great',
#  'job',
#  'hope',
#  'equality',
#  'general',
#  'still',
#  'valid',
#  'well',
#  'great',
#  'centralized',
#  'power',
#  'ruling',
#  'metaverse',
#  'much',
#  'room',
#  'improve',
#  'volunteer',
#  'community',
#  'pushing',
#  'one',
#  'day',
#  'push',
#  'marketing',
#  'would',
#  'big',
#  'pump',
#  'buy',
#  'hold',
#  'stake',
#  'coin',
#  'createa',
#  'passive',
#  'income',
#  'yooshi',
#  'official',
#  'following',
#  'myth',
#  'thread',
#  'last',
#  'week',
#  'much',
#  'eminent',
#  'oxford',
#  'colleague',
#  'prof',
#  'sir',
#  'andrew',
#  'pollard',
#  'making',
#  'point',
#  'myth',
#  '4',
#  'chart',
#  'showing',
#  'covid',
#  'case',
#  'uk',
#  'far',
#  'higher',
#  'european',
#  'country',
#  'misleading',
#  'http',
#  'co',
#  'c8x3ptidy2',
#  'patience',
#  'putting',
#  'work',
#  'today',
#  'knowing',
#  'nothing',
#  'going',
#  'happen',
#  'next',
#  'day',
#  'afghani',
#  'handcraft',
#  'suitable',
#  'source',
#  'income',
#  'afghanistan',
#  'kabul',
#  'yupe',
#  'many',
#  'nurse',
#  'friend',
#  'pindah',
#  'ke',
#  'saudi',
#  'experience',
#  'also',
#  'salary',
#  'mmg',
#  'besar',
#  'dekat',
#  'situ',
#  'untung',
#  'dapat',
#  'buat',
#  'umrah',
#  'know',
#  'legit',
#  'investment',
#  'platform',
#  'highly',
#  'secured',
#  'earn',
#  'passive',
#  'income',
#  'also',
#  'compound',
#  'earnings',
#  'job',
#  'hatiperi',
#  'vejamos',
#  'caso',
#  'tal',
#  'z',
#  'trov',
#  'carinha',
#  'dele',
#  'hoje',
#  'n',
#  'aparece',
#  'na',
#  'galeria',
#  'da',
#  'interpol',
#  'n',
#  'fa',
#  'ideia',
#  'motivo',
#  'ineg',
#  'vel',
#  'que',
#  'hoje',
#  'interpol',
#  'n',
#  'aprovou',
#  'inclus',
#  'e',
#  'se',
#  'negarem',
#  'pode',
#  'ficar',
#  'feio',
#  'para',
#  'stf',
#  'e',
#  'brasil',
#  'http',
#  'co',
#  'yuraxqg51w',
#  'contrarian',
#  'alert',
#  'plant',
#  'flag',
#  'argue',
#  'useless',
#  'point',
#  'feel',
#  'like',
#  'bos',
#  'smallbrains',
#  'game',
#  'job',
#  'recruiting',
#  'permanent',
#  'lectureship',
#  'organised',
#  'crime',
#  'amp',
#  'corruption',
#  'looking',
#  'new',
#  'colleague',
#  'w',
#  'expertise',
#  'study',
#  'organised',
#  'crime',
#  'corruption',
#  'amp',
#  'geographical',
#  'focus',
#  'detail',
#  'stop',
#  'saying',
#  'chart',
#  'obsession',
#  'need',
#  'increase',
#  'nickis',
#  'entry',
#  'matter',
#  'number',
#  'work',
#  'together',
#  'prepare',
#  'new',
#  'album',
#  'chart',
#  'one',
#  'song',
#  'expect',
#  'good',
#  'whole',
#  'album',
#  'every',
#  'feature',
#  'practice',
#  'album',
#  '100',
#  'going',
#  'woman',
#  'equality',
#  'opened',
#  'pineapple',
#  'juice',
#  'broke',
#  'nail',
#  'may',
#  'need',
#  'leave',
#  'work',
#  'causeeeeee',
#  'truly',
#  'feel',
#  'like',
#  'people',
#  'think',
#  'walk',
#  'park',
#  'shit',
#  'see',
#  'bos',
#  'work',
#  'hard',
#  'trying',
#  'accommodate',
#  'best',
#  'waiting',
#  'miracle',
#  'grandmother',
#  'surgery',
#  'cost',
#  'salary',
#  'enough',
#  'surgery',
#  'hopefully',
#  'good',
#  'people',
#  'want',
#  'help',
#  'tla',
#  'ha',
#  'created',
#  'new',
#  'resource',
#  'partnership',
#  'w',
#  'colleague',
#  'help',
#  'build',
#  'support',
#  'ed',
#  'wellbeing',
#  'combat',
#  'burnout',
#  'amp',
#  'potential',
#  'resignation',
#  'support',
#  'student',
#  'yieee',
#  'fairness',
#  'ang',
#  'tangkad',
#  'ko',
#  'sir',
#  'alex',
#  'ha',
#  'emotional',
#  'word',
#  'close',
#  'friend',
#  'former',
#  'united',
#  'colleague',
#  'big',
#  'smile',
#  'wednesday',
#  'love',
#  'colleague',
#  'sent',
#  'spotted',
#  'wa',
#  'stressful',
#  'week',
#  'thoughtful',
#  'leaving',
#  'spread',
#  'smile',
#  'mr',
#  'c',
#  'headteacher',
#  'please',
#  'show',
#  'support',
#  'hard',
#  'work',
#  'devotion',
#  'agenda',
#  'donating',
#  'today',
#  'dollar',
#  'go',
#  'directly',
#  'funding',
#  'gotv',
#  'digital',
#  'effort',
#  'view',
#  'made',
#  ...]

# %%
trainset_texts = [' '.join(content) for content in np.concatenate((non_sensitive_trainset.values, sensitive_trainset.values))]

train_all_texts = [' '.join(content) for content in train['content']]

test_all_texts = [' '. join(content) for content in test['content']]

# %%
trainset_texts
# Out:
# ['past year ha undeniably challenging testing physical mental emotional health help motivational advice savvy strategy staving burnout turned brittnea jones parkview behavioral health institute',
#  'sleeping giant 1 p2e game 2 whitepaper drop month 3 savior mint month 4 breeding delivered q1 2022 5 game launch q2 22 6 breeding stud service gameplay rental passive income project boom',
#  'name singalakha hold ndip logistics nelson mandela uni looking job past 5months amp 2 year experience previous internship appealing post available regard job post available aligned profession',
#  'sequel likely according warnermedia studio bos http co bfy7eelbih',
#  'united nation recognizes amp acknowledges persecution hindu minority asmt woman report published',
#  'two drunk lady work asked wanted take selfie wa like um ok said bos deserved payrise',
#  'fairness galing nung boy type ko',
#  'premise self identify part group premise certain group preferential treatment equity aka social justice result unscrupulous individual identify part preferred group sowing resentment solution equality meritocracy',
#  'fairness tho alan wrong lineker tweet like celebs speak outside area exactly improved level public discourse ha alan get quote tweeted amp put article like sum lot wrong twitter',
#  'hi fighting burnout reform wheel rule',
#  'case missed colleague',
#  'great oppose racism showed empathy black american try get stand colleague fellow indian player mohammed shami show oppose communalism',
#  'west virginia 2nd poorest state u rank 50th education 48th household income maybe rest 700k yacht think need constituent pay salary',
#  'city fan probably noticed since 100m move fairness',
#  'lmaooo asking mom permission could buy seventeen album still answer nowhere ask bts one advertise lazada rn like mnnhnhnhnhhn seventeen well bts seventeen workmate guess',
#  'hay nagresign one favorite workmate hay kkalungkot',
#  'using shamita fairness loyal attitude advantage shamita must aware',
#  'work week fixing food others meal fix would awesome sunsets53',
#  'funny dropped social distancing lockdown quickly work brought someone wa strict back want talk guess',
#  'urgent job seeker need employability boost get cv reviewed free hr professional info',
#  'transmission short range yeah airborne disease work tuberculosis spread simple probability dispersion comment mechanism transmission ha lot documented long range covid transmission',
#  'please kill filibuster please inact fairness doctrine please stop worrying seen great compromiser one compromise fascist criminal anyway lord chamberlain mistake please review 14th amendment section 3',
#  'job wel ariastaylorswift',
#  'weekend tsa nou di batla inheritance salary',
#  'reaching burnout ha nothing sunflower amp sunshine nobody care enough really get validate experience take care fine',
#  'hello husband searching job plz help short profile current profile seo related php coding website maintenance looking change job profile wordpress developer php developer plz help',
#  'thank talaga sa workmate kong tinapos lahat kahapon lahat ng email query ko hahahaha encoding na lang natira lt 3',
#  'still forward player job score like kane robertson arnold technically liverpool winger',
#  'going love find job create art love feel powerful going back track know going feel like eventually end hang',
#  'decarbonization mean enormous transfer wealth income oil producer oil consumer even oil consumer also lead renewables europe far east big winner u norway et al probably adjust opec big loser',
#  'ha tujhe bohot pata hai ipl ke match dekhne k liye paisa bhi hote hai kya tere pas loudu psl ki trophy ki kimat se jyada ipl k ek player ki salary hai',
#  'climate action vehicle deliver dignity opportunity equality ahead watch deputy secretary general remark',
#  '6 way company help employee overcome burnout distributed world',
#  'colleague told bought house wa gifted 30k grandma kind wealth trying sew kid grandkids life',
#  'frugal life putting extra money salary invest extra income give room spend want quality product loveeee life',
#  'meditate way burnout regular mindfulness meditation help work regular support thing get tough',
#  'brother remember salary ilu le country strong',
#  'think enough ha said heavy lifting australian psychologist especially melbourne done pandemic frontline worker struggling burnout saved countless life gp feel indebted',
#  'interested bacterial cell biology genetics phd position open group lund university study control polar growth cell shape streptomyces apply nov 12 info',
#  'goal gender equality gender harmony',
#  'excellent conversation access justice small claim court revolutionary court unique innovation broaden access justice way previously thought unachievable judiciary great job',
#  'hope equality general still valid well great centralized power ruling metaverse',
#  'much room improve volunteer community pushing one day push marketing would big pump buy hold stake coin createa passive income yooshi official',
#  'following myth thread last week much eminent oxford colleague prof sir andrew pollard making point myth 4 chart showing covid case uk far higher european country misleading http co c8x3ptidy2',
#  'patience putting work today knowing nothing going happen next day',
#  'afghani handcraft suitable source income afghanistan kabul',
#  'yupe many nurse friend pindah ke saudi experience also salary mmg besar dekat situ untung dapat buat umrah',
#  'know legit investment platform highly secured earn passive income also compound earnings',
#  'job hatiperi',
#  'vejamos caso tal z trov carinha dele hoje n aparece na galeria da interpol n fa ideia motivo ineg vel que hoje interpol n aprovou inclus e se negarem pode ficar feio para stf e brasil http co yuraxqg51w',
#  'contrarian alert plant flag argue useless point feel like bos smallbrains game',
#  'job recruiting permanent lectureship organised crime amp corruption looking new colleague w expertise study organised crime corruption amp geographical focus detail',
#  '',
#  'stop saying chart obsession need increase nickis entry matter number work together prepare new album chart one song expect good whole album every feature practice album',
#  '100 going woman equality',
#  'opened pineapple juice broke nail may need leave work causeeeeee',
#  'truly feel like people think walk park shit see bos work hard trying accommodate best',
#  'waiting miracle grandmother surgery cost salary enough surgery hopefully good people want help',
#  'tla ha created new resource partnership w colleague help build support ed wellbeing combat burnout amp potential resignation support student',
#  'yieee fairness ang tangkad ko',
#  'sir alex ha emotional word close friend former united colleague',
#  'big smile wednesday love colleague sent spotted wa stressful week thoughtful leaving spread smile mr c headteacher',
#  'please show support hard work devotion agenda donating today dollar go directly funding gotv digital effort',
#  'view made persona non grata mit wsj',
#  'research vlog training specialized youth athlete adolescent athlete suffer burnout overuse injury thrive good coaching amp support tip help adolescent athlete safely achieve high performance http co bojxxxnrzt',
#  'best passive income project community decides like 10 50 good project 100 one best 500 best one babycake',
#  'experienced teacher poorly paid compared graduate profession yet skill highly valued many industry writes current approach teacher pay flawed',
#  'arabic banner protest say governed el sisi order freedom peace equality',
#  'meet workmate occupation',
#  'value matter wellbeing matter work life balance work life blend',
#  'time nfts cryptocurrency giving young gen new way income like also say due worldwide shipping much pollution traffic created water surface',
#  'yung workmate ko simula nung nag resign ang fresh na nyaaaa inggit na inggit ako look happy new career sana',
#  'grant emergency use approval covid vaccine covaxin vaccine ha 78 percent efficacy two dos extremely suitable low middle income country said 333 million people fully vaccinated country',
#  'one important thought start work today remember work get salary family get life jai shree krishna radhe radhe',
#  'hello received bid yet art expressed feeling last year burnout found healed started journey artist new enthusiasm amp energy http co z05zjwt40j',
#  'recommend anyone job sale account manager chromatography mass spectrometry',
#  'growing number australia top business leader south asian heritage tell bos ambition learn hunger success',
#  'developer fairness many game implement uh oh monster time better hide gameplay mechanic almost always clunky boring amp annoyance',
#  'rep aoc advice dealing burnout job exhaustion',
#  'oh bos video got awseome check download page respond thumb',
#  'omega',
#  'ice cream fancam 1m view good job hiyyihlights',
#  'ha job offer tiny start company much salary help pay bill money money hinata start looking two guy burying head front computer 3 u company one',
#  'workmate getting kfc lunch birthday',
#  'rajasthan teacher lost job supporting pakistan t20 world cup say family member also',
#  'kenyan know power new income stream making money investment service doe exactly global fund manager kenyan access foreign currency investment right',
#  'careful doe cause burnout take break reviewing',
#  'hi please dm total stranger happen writer assistant asking pas script bos power make showrunners read script wanted asked read',
#  'kit arrived last sunday able post countdown anniv feel say hi new workmate tumbler tysm',
#  'lol like one ole burnout boy',
#  'burnout tends caused people want good job placed situation good job difficult takeaway acknowledge burnout caused intrinsic factor extrinsically http co js1ukkjdvb',
#  'feeling grateful may last thing mind time point emotional burnout important key navigating wild unpredictable time',
#  'power feel power social network critical career advancement navigate unwritten rule unforeseen challenge avoid burnout woman need inner circle female contact often overmentored amp undersponsored yes lellyoboh',
#  'hello manager would love would really help lot apply scholarship following axie month wa determined invest wa fired job would help lot get ahead',
#  'think sj keep warm thanks yesung kind heart happy met proud colleague brother partner life tell several time grateful love choi siwon yewonesday',
#  'competitive salary mean bill food budget competing see win every month',
#  'modern society mistaken equality sameness turn every difference ha become discriminatory sadhguru jaggi vasudev',
#  'quit job today',
#  'behance santarobein44e insight ring eltham plumber plumbing expert area arrive armed tool needed handle job first visit spend time dealing',
#  'one hundred unique delegators delegating u mean reliability fairness',
#  'met many high income earner salary around 13k 20k mainly working finance manage money 1 invest big chunk salary 2 invest kid plan kid education invest',
#  'saying union third party reinforcing bos misinformation worker union',
#  'spare nvme trouble shooting see get work win 7 i9 back delidded',
#  'exchange completely correct valuable cpd colleague',
#  'followed advice chapter 4 bos homeless',
#  '',
#  'drawing solution burnout',
#  'proud cymru first amp country island incorporate black amp ethnic history school curriculum looking forward cymru becoming independent enshrine equality amp fairness written constitution matter indycymru',
#  'im ready give salary',
#  'workmate wa complaining even shes sick hubby cant hold cook clean wife lucky cook clean ease',
#  'kek live btw linky bio ds3 bos grind',
#  'everybody wana bos realize bos always get paid last',
#  'big problem medicine honored publish global study assessing burnout amp quality life among surgeon finding 1 burnout 30 6 among spine surgeon 2 significant association burnout score amp quality life orthotwitter',
#  'footballer contract used template signing thing footballer win champion league get compensated winning aside regular wage salary case footballer win award get extra bonus',
#  'life someone monthly salary someone data',
#  'sadly work problem phone live mobile signal pathetic unless hang bedroom window',
#  'accomplished nothing excellent work today sure oke would proud brother always heart',
#  'thanks much excellent global participation first webinar n series four policy fix local news might work follow session recording detail upcoming event',
#  'lack boundary generate feeling overwhelm stress cause resentment result burnout webinar help setting boundary improve wellbeing wednesday 10 november 12 30pm 1 30pm online http co oj9mwkgudc',
#  'data received bos god bless thanks',
#  'welcome trying god work',
#  'much fairness ask rule rest u',
#  'climate change gender equality much young people leading way rutte sitting hearing thought answering question tune',
#  'prescribed death approach leave something value made favour parent immediate family fairness obligation mindful allah quran 2 180',
#  'tolerance freedom equality freedom justice objectivity science love competition interdependence',
#  'one job live extraordinary life umair hague',
#  'last two year challenging everyone one thing seems result burnout dive burnout look like push past http co unk9e65e3v',
#  'hey everyone account ha suspended day trying recover account know work long take account keep editing like',
#  'flexed bos finishing back work office puzzle working earlier day',
#  'long time burnout wa seen worker problem something needed fix self care yoga sleep going make rat race life',
#  'bravo bos',
#  'ethiopia ally truly committed gender equality amp human right must stop funding genocidal regime war crime unprecedented',
#  'thanks deleted old account decided make new start twitter know work going try ignore rubbish generally respond try say constructive thing respond might hard',
#  'issue ishan playing middle order team backing hardik job considering fit',
#  'get school work complete today got much',
#  'critical race theory gender equality democrat virginia biden administration pushing hobby horse instead fixing issue',
#  'bus company also starting report shortage driver bus driver leaving drive hgvs http co ycou1hi1pj',
#  'harry potter pierogies biscuit bos two food need try arlington',
#  'yes adhd med huge deal since diagnosis last fall good strategy accomplish lot without medication support take sooooooo much energy keep everything going regular thing without burnout depression',
#  'going make sure kyrsten sinema primaried follow u let get work',
#  'today got lovely heartbreaking response creator whose webcomic recently reviewed creator mentioned experiencing burnout getting discouraged low subscriber count view rereading review help keep going',
#  '2 friend work amp b day decided go theme park mutual friend workmate c called sick could tag along work call see come cover mum answer phone tell left b amp c theme park',
#  'brandon fired early 20 bos declaration taught one first foundational truth still believe today want lead must lead first',
#  'really wanted ask wa squid game job interview',
#  'beauty fairness rock roll 0',
#  'cry workmate told partnership merc past got driven around merc amg car race track got merc march',
#  'try think would really helped student fantastic mentor 3rd placement treated colleague would sit together bounce idea really made feel valued respected',
#  'doe look like touhou bos',
#  'learn source amp provide quality increase click 100 start ever regret making side income',
#  'one important way think architecture agency fight equality zero carbon design ethical approach human centered design planet centered action',
#  'ready two income household',
#  'joked workmate awkwardly fumbled way door need bring picnic basket outdoor work lunch laughed actually cute little picnic basket work lunch would great',
#  'one fewer child carbon saving 3 billion people bottom 50 income bracket emit 7 carbon people global north emit way carbon also fewer kid child problem consumption problem',
#  'ja mir hat e auch zu sehr gefallen',
#  'vote change want see tmc herald new era prosperity equality harmony',
#  'love recruiting venue manager one coventry transport museum one herbert art gallery museum hour 37 per week closing date 28th october 2021 info amp application form please visit',
#  'ever interested seeing work contacting site well http co r2gyzvhdpt',
#  '16 yr good governance corruption employing family member staying apartment demanding higher salary job angela merkel respect happy retirement',
#  'went glasgow sunday look guitar workmate walked amazing martin j40 thanks help amazing',
#  'remember back went cilegon 2 week pretty fun workmate many friend',
#  'new day energetic work',
#  'job producer king head theatre someone experience enthusiasm help u imagine realise show planned 220 seat theatre show celebrate richness lgbtq experience local national national international audience',
#  'large banner say governed uae directive el sisi freedom peace equality',
#  'struggling identity crisis ever stammer someone asks may give short answer naming j b put food table lucky enough also job love http co wvr5njuyxg',
#  '2010 nhl fined nj devil 3m clawed back draft circumventing salary cap league later refunded half fine today nhl fined blackhawks 2m covering sexual abuse h pointed radio today',
#  'eighmy facility improvement budget increase work',
#  'welcome bos',
#  'meet stand d40 set mark half gcse level taken uk every year independent education charity income reinvested back aqa charitable activity register today learn',
#  'time drink espresso otk totally stressed burnout overly joyful celebrate something',
#  'favour democracy equality honesty opposing tory socialism nh school cannot favour voting',
#  'true greg fairness rivalry back particularly utd liverpool really day agree rodgers though limited bringing u level need',
#  'remember workmate shouting girl passing fancied drink finished reply wa id rather eat',
#  'workforce suffering burnout decreased explore company setting aside meeting free hour day improve',
#  'working hard make end meet crossed order illegally http co m1lbig1qxi',
#  'lol e reach time salary mention woman life',
#  'guy work ha backbone education america since 1980s case wonder got',
#  'favourite kfc wa business party tower london year ago really bad food workmate left go eat never forget precious memory',
#  'put work become successful obsessed work average',
#  'divide incite stand people bengal believe equality foster inclusivity make voice heard voting tmc votefortmc',
#  'someone like dump token understands game understand power passive income',
#  'feminist person belives social political economic equality sex',
#  'non singer may realise voice powered muscle larynx vocal chord lose fitness exercised live vocal la vega last night show much work ha done pandemic prevented performing',
#  'huyo nurse si ako na salary already',
#  'want miss dr charmer bigg bos 15 please go app vote need support time ever vote voteforumarriaz umarriaz',
#  'ada opportunity dekat oversea gerak je boleh nak fight untuk salary dekat malaysia tapi tak berbaloi yang still ada energy nak fight good luck',
#  'actually want football pundit desire hear man explicitly demand friend loses job ultimately bit weird enough clearly highlight deficiency team',
#  'brotherhood equality nation soviet poster 1963',
#  'workmate ha gone blackpool week week whole seven day blackpool late october seven day blackpool late october',
#  'dream photo video full time anyone would like help reach dream quit day job either letting work even simple even telling like stuff social medium http co btxyeqvcxr',
#  'current launchpad based lottery system decide participate ido leaf room bot abuse system hold large portion allocation tactical measure ido scan introduce ensure fairness prevent bot attack',
#  'amazing know milton said something profound yet simple society put equality freedom get neither society put freedom equality get high degree',
#  'formatting always different add burnout beat',
#  'actually kind employer',
#  'crime alert security bos olaniyan amos charged court n35 million fraud',
#  'wa also probably one properly called work economics',
#  'welcome uk bos stay safe enjoy time o7',
#  'wealthy people rich rich people wealthy rich usually cash material asset high expense compared income show wealthy usually long term investment low expense compared income humble investing',
#  'wow luxury sure workmate tina would envious people went abroad holiday exotic location 70',
#  'probably people subconsciously hoping problem go away fairness sometimes doe people forget time wound heal naturally remember one fester amp snowball said dealing problem early still better strategy',
#  'sometimes hard call buddy help quick cash loose 100k never loose avoid awkwardness come asking download apply soft salary advance app',
#  'mar 29 libra bringing sense urgency extra push take action assert realm partnership issue involving beauty fairness compromise law may culminate',
#  'ha announced increase petrol price petrol price pakistan already expensive considering per caput income ha reduced tremendously past 3 year amp people purchasing power ha eroded due ever increasing inflation',
#  'jeez yeah thats lot work eager without fast forward stuff mean really good shit super fun',
#  'associate british value tolerance fairness newer british way value selfishness arrogance plain racist behaviour unfortunately union flag longer positive acceptable symbol',
#  'prepared still post country meet salary demand strike service country',
#  'tpunk tron busy time come ready burning special drop passive income way cool stuff tpunk holder tpunks',
#  'uncharted 4 fun light popcorn movie game hit quite bit emotional impact wa floored story nate kid meeting sully relationship brother workmate course wife 1 2',
#  'amp woke ceo super concerned equality eye cannot roll harder',
#  'word staffer phoning citizen threatening legal action publicly discussing allegation misconduct made end well bos',
#  'everytime waiter chat come always customer fault get paid enough restaurant ha salary structure',
#  'new survey data suggests two third quit job past year achieving financial freedom crypto total income 50k',
#  'haha good thinking close call someone knocked meant ring bell fortunately got work stripped yet',
#  'hope joy expressed politician big business removal restriction opening early special note uk could expect next month reality check doe think see different',
#  'career msg cancer scorpio amp pisces building new friendship career life find people work share similar hobby goal area interest passionate could specifically',
#  'know love coach rich ha something prove new gonna put ha succeeding human naturally crave change work harder new opportunity getting football team care ha potential',
#  'best first bos dialogue',
#  '50 000 day trnsmt festival 2021 sridhar wa silent stirring pot snp bos see',
#  'since lot people asking cc take ad issue wa matter equality versus equity twice ph decided conduct fundraiser member existing one ensure get something bday',
#  'oh wow thank message bro yes album delicious great job proud thank message hope meet soon thank inspirit tagged let know',
#  'recruiting motor claim validators growing business based exceptional opportunity join reputable organisation looking ambitious resilient talented individual join motor claim team http co xxkgicmrix',
#  'month burnout wa worst time ever like damn still wanna know fall behind guess see many amazing artist tl wanna become like right doe take time break',
#  'haha fairness parang lucky charm sa mga future mom wife sana soon na yung sa real jowa',
#  'thank god today great friend workmate',
#  'done bos download add download link bookmark device check respond',
#  'anyone looking accountant administrator gig friend dire need job full time part time good fresh quickbooks based nairobi dm lead appreciate',
#  'right journalist job asking one populist question would feel wa mother rather exploring real issue child face actually something',
#  'effortlessly time different source income may typical salary extra resource usually get one time big time income forget thankful affirm last time',
#  'guess prudent note adhd work coffee shop lol experience also universal',
#  'obviously raising income level par rest country right cdnpoli',
#  'set successfully worst common mistake idea grow build relationship fan avoiding burnout http co lxehdpznof sonarcccb',
#  'run loss making company pay salary rent etc company get huge market valuation surprising dont show profit banker go bonkers',
#  'fuck bos',
#  'crideble info 2000 alqaeda prisoner released taliban bagram pul e charkhi prison currently training along durand line isi ha begun recruiting fighter 30k afs salary osama dead alqaeda reemerging stronger',
#  'ugh found cool bos support trump anyone hiring actual okay person lemme know',
#  'thinking time finessed bos pay twice one pay period never got caught need work another dummy',
#  'labelled terrorist get arrested fired work passport revoken judicial recourse prove disprove http co 6cekzepxuf',
#  'seeing arn get stance still get fired everytime',
#  'get grindset 3 00am wake 2 hour pushup 5 00am masturbate 2 hour soft build mental toughness 7 00am 7 15am go work get fired calling n word 9 00am listen 2 hour lil boosie',
#  'tw abuse rape fan attending love tour atlanta wa physically assaulted show pit man snuck tried asking guard help care let u trend get guard fired harry style',
#  'pay 40m yr salary',
#  'owen patterson suspended parliament permanently 6 week business egregious misconduct would lead fired permanently please retweet agree let get twitteratie behind',
#  'fucking company fucking account get lock fucking fired',
#  'youngkin trump toady conspiracy theorist pro book ban science reproductive freedom election integrity public education equality diversity say trumpism vote youngkin racist policy fresh',
#  'want change job fortune 500 company give 10 salary increase another non international company give 20 choose',
#  'hope trooper barry move florida value exemplary officer unlike massachusetts domestic abuser shove wife face feces get fire humiliate http co mryhpelqcj',
#  'alan jones fired tough know love 1950s hope memory help woman get loan equal pay job indigenous vote child stolen illegal gay racism italian assimilating ruining au good ol day staygonebigot',
#  'could simone small man tight trouser give bos respect',
#  'nobody taught white people inherently racist made republican leader amp medium get folk fired taught systemic racism wa explicitly legal 1965 ha shaped society current day',
#  'secretary bitch bos',
#  'still waiting highlight inaccuracy quoted fairness ha extremely well ran scare campaign government medium',
#  'ask wth workplace mobbing believe part harassment involves sending fake employee job pollute work environment causing quit get fired top tactic usually filling bos amp workmate salacious lie',
#  '1 kneeling black life matter 2 advertisement fairness cream',
#  'nobody got shot untill rosenbaum attacked kyle rosenbaum called get someone shot kyle kyle fired shot people went kyle told wa active shooter shot self defense attacked victim',
#  'lowkey worst people actively deny break bos complain taking break coworkers facilitates environment new employee take break literally',
#  'ready jump ship quietly interviewing new company offering 15 raise',
#  'course end sem mid sem weirdest fucking shit project need complete pas course rather take week exam stress constant burnout tyvm',
#  'news black america telling truth get fired via',
#  'fairness point despite sharing multiple racist homophobic anti semitic text message moody guy mackay denied racist anti semite homophobe utterly kerb stomped vincent tan',
#  'silly bitch keep raking money corrupt fake go work together mtg rest insane',
#  'bos never work overtime bos best work overtime shit fairness',
#  'want get fired huh',
#  'someone going get fired lol',
#  'also remind artist often one person handling many job exhausting company literally hire entire department staff market product service try hard becuz burnout awful',
#  'tired want go work began long term job burnout nothing thing please bother ok',
#  'initial anxiety fuck need new job job market fucked wa kind awful always better job around corner comfortable place work would never happened get fired',
#  'new workmate hahahaha stay quitting job everything suck dad',
#  'make conspiracy theorist colleague think reptilian',
#  'chalice stream wa asked ti8 lgd could reunion besides ame chalice nah happen everyone expensive probably least expensive one p talked friend cn cn salary probably least 2x 5x sea west',
#  'bos youtube cause im fuckin islamic republic hear see youtube u bos',
#  'dw always get fired spreading video enough',
#  'miss congeniality 1 2 kinda good ish movie cause like fuck imma right thing go vibe compassionate hot girl doe better job told get fucked amp got fired r sad amp hot girl live happily ever',
#  'aku lagi nyari support nih utk ai tech company di jakarta pusat dm yah kalo minat salary 7jt thp',
#  'wear wear shirt sits throne sit floor see equality woohoo 525252555555 29 64',
#  'holy shit supposedly torrid went woman job tried get fired criticizing design treatment customer',
#  'fed fucking job fucking bos co worker quit',
#  'result strike vote clearer wa announced 75 4 participating 100 voted yes woe unto airline bos dare mess risk summoning chaos',
#  'deep burnout actually collection screaming cat trench coat',
#  'get intern fired',
#  'thought dems equality said men clearly woman standing 2nd left bun tucked hat case missed oh white supremest black man well disgraceful entire agenda divide',
#  'female bos werey go carry belle quit job make talk say na girl lie',
#  'anyone belief germany sense fairness righteousness please recall germany attitute even killed 6 million jew mention colonial crime liitle gray man bring grief',
#  'stand awful working environment going jump ship woe next person take position hahaha beware company looking safety engineer day',
#  'girl bos shit cute whatever much admire woman simply taken care men lift finger real winner life',
#  'today ha shit customer wa trynna say wa giving attitude saying gonna fuck fucking wish please give reason get fired',
#  'day get fired day quit happiest day life need either come soon',
#  'fuck go budget one project get threatened fired',
#  'noooooo way bitch could handle shit endured month everyone talked shit delete account change name meanwhile still dealing blowback like started campaign get fired',
#  'stats speak 1 3 gps planning leave next 5 year 1 2 retire early retirement trebled last 8 year due stress 1 2 rest leaving due burnout gps almost universally working 12 hour day faced endless abuse',
#  'hungry guy grows cabbage patch pavement contravention law police car swoop health min resigns alleged misuse fund intended sick dying rewarded r1 2m salary',
#  'wa easy call black woman bully silent brought left respond beyond fake disappointed andy let get easily lisa absolute worst fired',
#  'protester threaten chase extinguishing dumpster fire started ziminski fire gun air pointing yelling get rosenbaum last word f k happened rittenhouse fired single shot',
#  'coworker get fired dipshittery',
#  'agree point point older people expect higher salary someone starting job market shocking know maybe reason always ask current salary 20',
#  'mf called fucking liar bc got stock steam card wrong told taking mgmt complain abt go ahead cunt great could get fired since im tired b anw',
#  'cant wait joe dumbass get fired tomorrow',
#  'doe apply every right seek religious exemption mean gonna get employer ha accept technically fired reason ny job fight employer odds lose job',
#  'homie stay killing eh',
#  'supervisor struggling overworked cynical director constantly reminded expectation burnout suicide high among clinician bad client high bad employer',
#  'good job finn men agree wait telling richard sit amp stfu wa talking trans experience guess apply lesbian enjoy getting hearty back slap dude big laugh lesbian raped',
#  'nafisa atari school teacher indian state rajasthan terminated job celebrated pakistan win india match nafisa ha terminated job citing whatsapp story expressed joy pakistan victory indvpak',
#  'many month tried demonize u ostracize u censor u get u fired prosecute u domestic terrorist short worked destroy life therefore table turned must dedicate destroying fair',
#  'workmate used word namamakla insult another workmate via online meeting people around see fugly inside',
#  'ppl get fired bc type like im supposed care like im sorry im going hospital catch c nurse bc shes v xed 8 month ago scared shit like abt 2022',
#  'peep toe heel pantyhose clad leg get fired tina would love one one time worship gam heel office please reign office bos',
#  'victorian hell amp andrew created broken state already vxd unvxd anxiety frustration fear amp completely divided lose job amp suffer seems govs way forward many broken life',
#  'care awful lot fight equality disagree marginalising trans people benefit woman said gc ideology threat people every individual gender crit dangerous ideology reason wa questioned',
#  'vinsome sears black woman win call white supremacist mean stupid rock garden smarter job espn oh yeah fired get life',
#  'ap news claimed one asked fbi investigate school protester patriot act terrorism ap culture war player might well cite tucker carlson mandate amp draft delicate protest riot death ensue fairness imperative agreed',
#  'fairness absolutely valid comparison lmao make use body drive engagement tech field belong u wanna n fact blew make look like bitch',
#  '9 driver committed suicide including brother kenny chow hunger strike 9 day fighting 6000 medallion owner driver plus family justice fairness survival',
#  'bruh almost shat pant workmate spoke wa looking 18 art',
#  'lol e una go shirt fight woman anything term disrespect woman go dey hear bos wa man',
#  'saw something today proved still surprised workmate retreved strong smelling bin ate front horrified onlooker wa rank wa wrapper likely date fuck',
#  'glennyoungkin another trump clone big lie spreading white supremacist empowering insurrection loving anti science anti equality anti democracy misogynist turn va texas florida virginia vote',
#  'gone get fired',
#  'way cope amount work rn start hard drug',
#  'know anything michael lassie looking another job worth hassle minimum wage funny thing job run 3 different company one nh say folk wanting',
#  'infringed first amendment right twitter government government restrained 1a people get fired 1a protected speech time walk bos office call pedophile see happens',
#  'literally boiling right livid freaking fuck young woman ha endure brainwashed crass base teacher essentially grooming young woman men prostitution want help get fired exposed live bay area op',
#  'stupid workmate laying sofa lt lt',
#  'ive thinking trying give benefit doubt cant really anymore dude sucking dick trading full time income coming wherever else anywhere besides ape',
#  'dpt job offer bru dkt sngt dkt rumah convenient go work save rm200 300 transport cost time salary wise emmmmmmmm ok la current company counter offer rm900 increment current salary tpi tk suka kerja kt company ni sbb culture',
#  'bos man got high bought u lunch',
#  'hey need move another company lot girl great afternoon tea',
#  'midget threw tantrum poch subbed ever since warpath get fired little emperor complex ha year ruling barcelona smfh',
#  'also understand trumpism also fear losing superiority even lowest feel non white trump manifested fear realization feeling forgotten emphasis equality wa back door nothing new regenerated',
#  'q2 hired female contractor build addition home slept shoddy work fired wa w fianc e busted wall like koolaid man told fianc e everything get fianc e back help sbcchat',
#  'remains humanity system preference table justice fairness guarantee error toothless democracy taunted oblivion image mobile world congress barcelona 2016',
#  'see spectacle girl bos woman empowerment used derail radical feminism kwanza venye election zina karibia whew',
#  'bos ha sexiest tapered finger virgo finger scream water placement',
#  'space tech growing like crazy want always date everything learn time mean free time social life shitty relationship first burnout 25',
#  'said nigga pls white bos wa cappin wife think imma get fired',
#  'baby 3 3k explicit maid cafe definitely last place jungkook thought would visit bos kim namjoon public sex rough sex slapping exhibitionism voyeurism yg maid costume link',
#  'activist burnout terrible learnt hard way happens lot way creep unfortunately ran character space',
#  'yeah fuck people flawed fine would man people stated wa literal salt earth ever act way man people get heated shit kalisto worked man gross fired jericho go',
#  'even bleed girl bos blood weep working woman workplace tear ive never even seen spit shes charge spit',
#  'guess funny mom breathe allergy asked get medicine morning said would get home without told fine bitch breathe work 8 hour shift without ability breathe',
#  'principal need get fired',
#  'exactlyyyyyy bos mom around lie tf pressed nigga',
#  'think imma get suspended tell bos drop dead',
#  'overtime overtime fuck overtime want overtime pay shit',
#  'ex republican simply want part uk united one country equality republican ha seen complete folly governed il ireann',
#  'politician act though accosted constituent job obligation constitutional duty listen u people know folk voted selfish ungrateful asshole office first goddamn place',
#  'looking new job working ai department gxxgle three year still job interested boss contact',
#  'would probably horrendous group chat guy ni best mate mixture prod catholic sectarian abuse get hurled around group chat would get people fired wa public typical mate',
#  'could predicted someone got start lying try get people fired teaching racism would approve lying get people fired teaching racism',
#  'proposing resign prefer get fired victim shaming student wa sexually assaulted male student admitted police backwards action stop enoughisenough',
#  'someone need get fired idc better',
#  'given ha duty equality fairness sure ensure mean least two headline story day devoted murder woman men maybe finally bring home reality',
#  'lol wake bogus excuse cash salary ha 25 50k year say getting 100k per annum last decade 1m right buy 100m worth property time paper liquid right',
#  'love nigga work outta state',
#  'takahiro karasawa ha large income',
#  'seriously reach people need expose teacher amp get fired essentially pimping grooming young people prostitution predatory amp inappropriate either profiting sex industry sick heinzsight2020',
#  'tory uk reckon need albo job',
#  'yesterday colleague said something quoting rest life get back phone tell fuck fuck',
#  'looking new job doe anyone need resume',
#  'supposed help master diluc get ready bed master diluc helping undress oh dear fired',
#  'really amazing bari wei publicly without shame university suggestion professor anti semite get fired make living writing article evil cancel culture woke censorship academia',
#  'woke morning dream competency based interview process made incredibly angry wa like dream wa trying make aware late capitalist construct riff fairness whilst simultaneously maintaining status quo',
#  'wa supporting max saw tweet gain love bos shame',
#  'dig pre 2018 archive still get photo president chamisa sg hwende even doe mean one sent ditch former bos khupe dhagi political violence deserves condemnation explanation',
#  'logistics financed 1ton truck need 4 5 load per week r15 cost per km target 4800km per month r72 000 gross per month cost diesel travel cost driver salary bank repayment may amount r35 000 profit may r37 000',
#  'present salary 1000 per month',
#  'u go u given z security fraud forged certificate get govt job u blow tax money clear indication u n ur party playing game maharashtra break',
#  'hope get fired lose stupid case health care worker approve science cause religion even f cking pope biggest christian religion world said wa okay gtfo',
#  'partly kidding abt getting fired still even called back asap tell audacity swear call liar countless time sir dont get paid enough deal sumn like u',
#  'damn forgot quad mariah ijs enough woman laid hand others get fired fight make good tv andy love',
#  'intern hope u get fired',
#  'yes well probably asshole call employer try get fired like colleague speaking punk 80 like homogeneous group thought way lmao dunno punk whatever',
#  'letter editor fired anti vaccine teacher get little sympathy reader via',
#  'former bos opening business company based wuhan china also already stole someone else platform copyright violation grifter stop grifting',
#  'get fired full',
#  'got fired wwe vince going hire ever whether trying kiss vince get job criticizing aew way bitter bad look bischoff turning cornette old age',
#  'saw vid easy watch guy tried get end gun point away kyle yanked back aimed fired shot fucking head wa execution self defense even cop would jailed',
#  'well maybe right people get fired control people people facing negative outcome due managed racist fire people continues system racist oppression think',
#  'feel like amazing partner week nope sleep neighbor two cousin get fired hitting bos today',
#  'know glad anyone public service job fired stupid selfish get vaccinated need stupid selfish people working medical profession profession involves health amp safety citizen',
#  'nina work bitch get fired',
#  'bos na lie na go dump ftm go 1 tell truth',
#  'colleague mine talk japanese im punching throat ripping vocal cord whore',
#  'need help ive asking year got eviction letter negitive income none lost 46lbs starving one give flying fuck people r poor n really suffering think suicide cuz im sick n tired living broke rather die',
#  'like fake outrage say fuckin watch said stupid shit social medium justice find get fired job',
#  'time prosecute anti democracy insurrectionist house senate replace people try overthrow government 1 6 committee need get urgently serious doe garland need fired',
#  'cared racism vote racist right trump wa close hitler get actually hitler open eye woman dems party freedom equality justice',
#  'want guy know get fired saying fuck president code loser fink',
#  'called many x work part day shift even hr hospital short unless govt amp admin address understaffing workload lack ft position burnout violence abuse amp continue amp patient care suffers write mpp',
#  'new apex map fucking suck whoever fuck designed shit need get fired asap',
#  'fairness advertising preemptive caveat warning found way twitter hot tub thread mostly tweet really depressing shit like neo nazi isi political violence etc asshole cat',
#  'want get vaccine take note 1000 american dying every single day amp trump think vaccine amp election lost trump victim trump ever gaf fired',
#  'colin kaepernick get cut never play another nfl taking knee social injustice let go brandon pilot fired never fly another passenger plane talking pro fascist shit plane intercom',
#  'wow cult emotion real really done great job brainwashing',
#  'red wall idiot inquest heard authority dealt miss day benefit claim made 28 error managing case miss day diagnosed unstable personality disorder saw income go 228 week 60',
#  'basically okay people get fired get vaccinated illegitimate administration violating right left leaning liberal seem care sleepy joe dictator plain simple un american',
#  'waqar younis ha apologised think mean fear generated reaction social medium could mean loses job commentator amp never work india anyways learn maharaja prithviraj chauhan people forgiven',
#  'alan jones get fired stupid left twitter',
#  'fairness probably clapping company truck',
#  'seriously figure stopping snapping customer long time regular ready get fired idgaf',
#  'several hour game none team india member spoken colleague india see spike islamophobia heavy cricket defeat pakistan',
#  'adulting lot man feeling like constant stage burnout mad stress time even lot good sheer amount responsibility od need 20 clone',
#  'sleeping bos choice melt leave job matter shit held stripped man penis forced struggling cry come inside comparable']

# %%
cv = CountVectorizer()
trainset_fit = cv.fit(trainset_texts)
train_all_count = cv.transform(train_all_texts)
test_all_count = cv.transform(test_all_texts)

# %%
train_all_count
# Out:
# <400x2933 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6031 stored elements in Compressed Sparse Row format>

# %%
tfidf = TfidfTransformer()
train_tfidf_matrix = tfidf.fit_transform(train_all_count)
test_tfidf_matrix = tfidf.fit_transform(test_all_count)

# %%
train_tfidf_matrix
# Out:
# <400x2933 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6031 stored elements in Compressed Sparse Row format>

# %%
model = MultinomialNB()
model.fit(train_tfidf_matrix, y_train)
# Out:
# MultinomialNB()

# %%
model.score(test_tfidf_matrix, y_test)
# Out:
# 0.76

# %%
pred = model.predict(test_tfidf_matrix)
acc = 1 - np.sum(np.abs(y_test - pred)) / len(y_test)
print(acc)
# Out:
# 0.76

# %%
y_pred = model.predict_proba(test_tfidf_matrix)
fpr, tpr, thresholds = roc_curve(y_test, y_pred[:,1])
auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(5,5), dpi=100)
plt.plot(fpr, tpr)
plt.title('roc = {:.4f}'.format(auc))
plt.xlabel('fpr')
plt.ylabel('tpr')
# Out:
# Text(0, 0.5, 'tpr')

# %%
from sklearn import datasets,linear_model,svm

def test_LinearSVC(*data):
    x_train,x_test,y_train,y_test=data
    cls=svm.LinearSVC()
    cls.fit(x_train,y_train)
    print('SVM')
    print('Coefficients:%s, intercept %s'%(cls.coef_,cls.intercept_))
    print('Score: %.2f' % cls.score(x_test, y_test))


test_LinearSVC(train_tfidf_matrix,test_tfidf_matrix,y_train,y_test)
# Out:
# SVM
# Coefficients:[[ 0.12638946  0.35026334  0.10026754 ...  0.10093286  0.18623808
#   -0.18756216]], intercept [-0.32480777]
# Score: 0.73

# %%
def test_SVC_Linear(*data):
    x_train,x_test,y_train,y_test=data
    cls=svm.SVC(kernel='linear')
    cls.fit(x_train,y_train)
    print('非线性分类SVM采用线性核')
    print('Coefficients:%s, intercept %s'%(cls.coef_,cls.intercept_))
    print('Score: %.2f' % cls.score(x_test, y_test))

test_SVC_Linear(train_tfidf_matrix,test_tfidf_matrix,y_train,y_test)
# Out:
# 非线性分类SVM采用线性核
# Coefficients:  (0, 1900)	0.27090763637813564
#   (0, 1638)	0.27090763637813564
#   (0, 1208)	0.27090763637813564
#   (0, 1035)	0.27090763637813564
#   (0, 552)	0.27090763637813564
#   (0, 495)	0.27090763637813564
#   (0, 2429)	0.25371322602635765
#   (0, 2318)	0.25371322602635765
#   (0, 2178)	0.25371322602635765
#   (0, 1798)	0.25371322602635765
#   (0, 1579)	0.25371322602635765
#   (0, 114)	0.25371322602635765
#   (0, 2421)	0.2577086093666747
#   (0, 2417)	0.2577086093666747
#   (0, 1379)	0.2577086093666747
#   (0, 689)	0.2577086093666747
#   (0, 636)	0.2577086093666747
#   (0, 2457)	0.34721373463272837
#   (0, 2383)	0.34721373463272837
#   (0, 1286)	0.34721373463272837
#   (0, 994)	0.34721373463272837
#   (0, 513)	0.5586138064245166
#   (0, 2921)	0.221121694278111
#   (0, 2812)	0.221121694278111
#   (0, 2105)	0.221121694278111
#   :	:
#   (0, 30)	-0.12798105276400748
#   (0, 28)	0.06273585756290764
#   (0, 2908)	0.3630631195209456
#   (0, 2710)	-0.09039187265085041
#   (0, 2683)	0.09859842885403802
#   (0, 2574)	-0.09039187265085041
#   (0, 2460)	-0.22665634774956028
#   (0, 2443)	-0.09039187265085041
#   (0, 2245)	-0.09039187265085041
#   (0, 1921)	-0.09039187265085041
#   (0, 1886)	-0.5145386598207669
#   (0, 1869)	-0.09039187265085041
#   (0, 1700)	-0.09039187265085041
#   (0, 1642)	0.04230108627365631
#   (0, 1399)	0.10653515754854269
#   (0, 1349)	-0.09039187265085041
#   (0, 1211)	-0.8265612046265385
#   (0, 1197)	0.20459561358381037
#   (0, 1164)	-0.07019409634530742
#   (0, 850)	-0.4547436273956404
#   (0, 472)	-0.08457504501854862
#   (0, 413)	-0.7037462080486577
#   (0, 392)	-0.09039187265085041
#   (0, 311)	-0.09039187265085041
#   (0, 121)	-0.48990861733116503, intercept [-0.44685947]
# Score: 0.75

# %%
from sklearn.neighbors import KNeighborsClassifier
#定义随KNN分类器  参数N为邻居数目
knn = KNeighborsClassifier(n_neighbors=10)
#训练过程  X为特征向量，y为标签数据/向量
knn.fit(train_tfidf_matrix, y_train)
knn.score(test_tfidf_matrix, y_test)
# Out:
# 0.73

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
import time

NBM = [SVC(kernel='linear', C=0.5), 
       SVC(kernel='rbf', C=0.5, gamma='auto'),
       SVC(kernel='poly', C=0.5, degree=3), 
       KNeighborsClassifier(n_neighbors=11), 
       MultinomialNB(),
       DecisionTreeClassifier(max_depth=15, min_samples_split=5), #防止过拟合将树深设为10
       AdaBoostClassifier(DecisionTreeClassifier(max_depth=15, min_samples_split=5),
                                                 n_estimators=200, learning_rate=0.8),#选择决策树，迭代000次，学习率为0.8
       RandomForestClassifier(n_estimators= 200, max_depth=10)]
NAME= ["LINEAR","RBF","poly", "KNN_N11", "MNB","DCT", "Boosting_Ada", "Bagging_RF"]
for itr, itrname in zip(NBM, NAME):
    #训练过程
    print("Training...")
    t1 = time.perf_counter()
    itr.fit(train_tfidf_matrix, y_train)
    t2 = time.perf_counter()
    print("Applying...")
    y_train_pdt = itr.predict(train_tfidf_matrix)
    t3 = time.perf_counter()
    y_test_pdt = itr.predict(test_tfidf_matrix)

    dts1 = len(np.where(y_train_pdt==y_train)[0])/len(y_train)
    dts2 = len(np.where(y_test_pdt==y_test)[0])/len(y_test)
    
    acc1 = accuracy_score(y_train_pdt, y_train)
    acc2 = accuracy_score(y_test_pdt, y_test)
    
    pre1 = precision_score(y_train_pdt, y_train)
    pre2 = precision_score(y_test_pdt, y_test)
    
    rec1 = recall_score(y_train_pdt, y_train)
    rec2 = recall_score(y_test_pdt, y_test)

    print("model：{} accuracy:{:.3f}%, precision:{:.3f}%, recall:{:.3f}%, time：{:.2f}s".format(itrname, acc1*100, pre1*100, rec1*100, t2 - t1))
    print("model：{} accuracy:{:.3f}%, precision:{:.3f}%, recall:{:.3f}%, time：{:.2f}s".format(itrname, acc2*100, pre2*100, rec2*100, t3 - t2))
# Out:
# Training...
# Applying...
# model：LINEAR accuracy:84.000%, precision:62.130%, recall:100.000%, time：0.02s
# model：LINEAR accuracy:74.000%, precision:33.333%, recall:85.714%, time：0.02s
# Training...
# Applying...
# model：RBF accuracy:57.750%, precision:0.000%, recall:0.000%, time：0.02s
# model：RBF accuracy:64.000%, precision:0.000%, recall:0.000%, time：0.02s
# Training...
# Applying...
# model：poly accuracy:59.000%, precision:2.959%, recall:100.000%, time：0.03s
# model：poly accuracy:65.000%, precision:2.778%, recall:100.000%, time：0.02s
# Training...
# Applying...
# model：KNN_N11 accuracy:76.000%, precision:50.888%, recall:86.869%, time：0.00s
# model：KNN_N11 accuracy:71.000%, precision:36.111%, recall:68.421%, time：0.01s
# Training...
# Applying...
# model：MNB accuracy:99.000%, precision:97.633%, recall:100.000%, time：0.00s
# model：MNB accuracy:76.000%, precision:41.667%, recall:83.333%, time：0.00s
# Training...
# Applying...
# model：DCT accuracy:88.750%, precision:73.964%, recall:99.206%, time：0.01s
# model：DCT accuracy:75.000%, precision:41.667%, recall:78.947%, time：0.00s
# Training...
# /Users/yhl125/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Applying...
# model：Boosting_Ada accuracy:100.000%, precision:100.000%, recall:100.000%, time：2.04s
# model：Boosting_Ada accuracy:64.000%, precision:58.333%, recall:50.000%, time：0.06s
# Training...
# Applying...
# model：Bagging_RF accuracy:81.250%, precision:55.621%, recall:100.000%, time：0.26s
# model：Bagging_RF accuracy:73.000%, precision:27.778%, recall:90.909%, time：0.02s

# %%
#text = "@Alice My name is Bob, I work in Microsoft. #highqualityman https:bscn3789de.com"
#text = "Today is my Birthday."
#text = "My salary is $2000 per month"
#text = "My boss Roan is a foolish man"
#text = "I hope Alice get fired tommorrow"
#text = "work makes me disgusting"
#text = "My workmate is nice"
#text = "My workmate is bad"
#text = "My employee John is good"
text = "My employee John is good but mean"
#text = "My employee John is shameless"
#text = "My employee John is stupid, but he pays me a lot"

df = pd.DataFrame({"text":text},index=["0"])

df['text'] = df['text'].str.lower()
df['text'] = df['text'].apply(lambda string: ' '.join([word for word in string.split(' ') if not word.rstrip(' ').startswith('@')]))
df['text'] = df['text'].apply(lambda string: ' '.join([word for word in string.split(' ') if not word.rstrip(' ').startswith('#')]))
df['text'] = df['text'].apply(lambda string: ' '.join([word for word in string.split(' ') if not word.rstrip(' ').startswith('http')]))
df['text'] = df['text'].apply(text_process)
print(df['text'])
# Out:
# 0    [employee, john, good, mean]
# Name: text, dtype: object

# %%
clf = MultinomialNB(alpha = 0.001, fit_prior=False).fit(train_tfidf_matrix, y_train)
print(df['text'])
text_content = [' '.join(content) for content in df['text']]
print(text_content)
print('---')

text_count = cv.transform(text_content)
print(text_count)
print('+++')
text_tfidf_matrix = tfidf.fit_transform(text_count)
        #print(text_tfidf_matrix)

        #print(text_tfidf_matrix.toarray())
        #text_tfidf_array = text_tfidf_matrix.toarray()
        #if (text_tfidf_array > 0.5).any():
        #    print(1)
pre = clf.predict(text_tfidf_matrix)
print(pre)

#clf = MultinomialNB().fit(train_tfidf,classtags_list)
# Out:
# 0    [employee, john, good, mean]
# Name: text, dtype: object
# ['employee john good mean']
# ---
#   (0, 855)	1
#   (0, 1124)	1
#   (0, 1621)	1
# +++
# [1]

# %%
doc = nlp(text)
print(*[f'entity: {ent.text}\ttype: {ent.type}' for sent in doc.sentences for ent in sent.ents], sep='\n')
for ent in doc.ents:
    if ent.type == 'PERSON':
        print("You may leak 'name' information.")
# Out:
# entity: John	type: PERSON
# You may leak 'name' information.
